# %%
import pandas as pd

# %%
import numpy as np

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
import joblib

# %% [markdown]
# Импортируем данные:

# %%
df = pd.read_csv('ДЗ_2_Прогнозирование_оценки_за_экз_по_ТОЭ.csv')
df.head(10)
# Out:
#                 Отметка времени  Итоговая оценка за экзамен по ТОЭ  \
# 0  2024/09/30 11:51:10 PM GMT+3                                5.0
# 1  2024/09/30 11:53:32 PM GMT+3                                3.0
# 2  2024/09/30 11:53:33 PM GMT+3                                3.0
# 3  2024/09/30 11:57:50 PM GMT+3                                3.0
# 4  2024/09/30 11:59:56 PM GMT+3                                4.0
# 5  2024/10/01 12:00:03 AM GMT+3                                3.0
# 6  2024/10/01 12:01:01 AM GMT+3                                3.0
# 7  2024/10/01 12:07:44 AM GMT+3                                3.0
# 8  2024/10/01 12:15:24 AM GMT+3                                NaN
# 9  2024/10/01 12:19:08 AM GMT+3                                5.0
#
#    С какого раза вы сдали экзамен по ТОЭ (если улучшали оценку, так же указать с какого раза получили желаемую оценку)  \
# 0                                                1.0
# 1                                                1.0
# ...

# %% [markdown]
# Видим, что есть некоторые пропуски в данных, заполним NaN нулями:

# %%
df = df.fillna(0)

# %% [markdown]
# Определим целевую переменную и признаки:

# %%
X = df.drop(columns = ['Итоговая оценка за экзамен по ТОЭ'])

# %%
Y = df['Итоговая оценка за экзамен по ТОЭ']

# %% [markdown]
# Преобразование в числовой формат:

# %%
X = pd.get_dummies(X, drop_first = True)

# %% [markdown]
# Разделение на обучающую и тестовую выборки:

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

# %% [markdown]
# Модель регрессии:

# %%
model = LinearRegression()

# %% [markdown]
# Обучение:

# %%
model.fit(X_train, Y_train)

# %% [markdown]
# Предсказания на тестовой выборке:

# %%
Y_th = model.predict(X_test)

# %% [markdown]
# Оценка ошибок предсказания:

# %%
mse = mean_squared_error(Y_test, Y_th)
r2 = r2_score(Y_test, Y_th)

# %%
print(f'Mean Squared Error: {mse}')
print(f'R^2 Score: {r2}')

# %% [markdown]
# Mean Squared Error: 0.7463693425652542
# R^2 Score: -0.40661914560374846
